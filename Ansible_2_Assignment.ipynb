# %% [markdown]
# #Ansible-2 Assignment
#
# 1. Write Ansible playbooks to automate the setup and configuration of a web
# server (e.g., Apache or Nginx)?
#
# - Aim:
#
# To automate the installation and configuration of a web server using Ansible playbook.
#
# **Procedure**:
#
# Installed and configured Ansible
#
# Created inventory file for localhost
#
# Wrote Ansible playbook to:
#
# install Nginx
#
# start & enable service
#
# deploy custom website page
#
# Executed playbook using ansible-playbook
#
# Verified output using curl and service status
#
# **Result:**
#
# Web server successfully configured using Ansible automation.
#
# ![Screenshot 2026-01-23 092952.png](data:image/png;base64,...)
#
#
#
#
#
# ![Screenshot 2026-01-23 093032.png](data:image/png;base64,...)
#
#
#
#
#
# ![Screenshot 2026-01-23 093114.png](data:image/png;base64,...)
#
#
#
#
#
#
#
# ![Screenshot 2026-01-23 093312.png](data:image/png;base64,...)
